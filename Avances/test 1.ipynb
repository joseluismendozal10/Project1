# %%
import pandas as pd
import json as json
import matplotlib.pyplot as plt 

PGJ_input=pd.read_csv("Carpetas de Investigación PGJ CDMX.csv",sep=";")
PGJ_input.head()
# Out:
#    año_hechos mes_hechos         fecha_hechos  \
# 0      2017.0      Junio  2017-06-19 10:00:00
# 1      2016.0  Noviembre  2016-11-15 12:00:00
# 2      2017.0      Junio  2017-06-19 05:00:00
# 3      2017.0      Junio  2017-06-19 06:00:00
# 4      2017.0      Marzo  2017-03-13 12:00:00
#
#                                               delito  \
# 0                       ROBO A NEGOCIO SIN VIOLENCIA
# 1                                            DESPOJO
# 2  ROBO A PASAJERO / CONDUCTOR DE TAXI CON VIOLENCIA
# 3     ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 4                                 ABUSO DE CONFIANZA
#
#                                     categoria_delito  \
# 0                             DELITO DE BAJO IMPACTO
# 1                             DELITO DE BAJO IMPACTO
# 2                             DELITO DE BAJO IMPACTO
# 3  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
# 4                             DELITO DE BAJO IMPACTO
#
# ...

# %%
PGJ_input.head(5)
# Out:
#    año_hechos mes_hechos         fecha_hechos  \
# 0      2017.0      Junio  2017-06-19 10:00:00
# 1      2016.0  Noviembre  2016-11-15 12:00:00
# 2      2017.0      Junio  2017-06-19 05:00:00
# 3      2017.0      Junio  2017-06-19 06:00:00
# 4      2017.0      Marzo  2017-03-13 12:00:00
#
#                                               delito  \
# 0                       ROBO A NEGOCIO SIN VIOLENCIA
# 1                                            DESPOJO
# 2  ROBO A PASAJERO / CONDUCTOR DE TAXI CON VIOLENCIA
# 3     ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 4                                 ABUSO DE CONFIANZA
#
#                                     categoria_delito  \
# 0                             DELITO DE BAJO IMPACTO
# 1                             DELITO DE BAJO IMPACTO
# 2                             DELITO DE BAJO IMPACTO
# 3  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
# 4                             DELITO DE BAJO IMPACTO
#
# ...

# %%
PGJ_input["año_hechos"].unique()
PGJ_input_alcaldia=PGJ_input.groupby("alcaldia_hechos").count()
PGJ_input_alcaldia
# Out:
#                                   año_hechos  mes_hechos  fecha_hechos  \
# alcaldia_hechos
# ABALA                                      1           1             1
# ABASOLO                                    2           2             2
# ACAMBARO                                   1           1             1
# ACAMBAY                                    3           3             3
# ACAPULCO DE JUAREZ                        41          41            41
# ACATZINGO                                  2           2             2
# ACAXOCHITLAN                               1           1             1
# ACAYUCAN                                   2           2             2
# ACOLMAN                                   22          22            22
# ACTOPAN                                    1           1             1
# ACULCO                                     1           1             1
# AGUA DULCE                                 1           1             1
# ...

# %%
alcaldias_df = PGJ_input_alcaldia.loc[['ALVARO OBREGON', 'XOCHIMILCO','TLAHUAC','TLALPAN', 'VENUSTIANO CARRANZA', 'CUAUHTEMOC', 'AZCAPOTZALCO',
                       'IZTAPALAPA', 'BENITO JUAREZ', 'CUAJIMALPA DE MORELOS', 'GUSTAVO A MADERO', 'MIGUEL HIDALGO', 'IZTACALCO',
                       'LA MAGDALENA CONTRERAS', 'COYOACAN', 'MILPA ALTA']].reset_index()
alcaldias_df
# Out:
#            alcaldia_hechos  año_hechos  mes_hechos  fecha_hechos  delito  \
# 0           ALVARO OBREGON       51006       51006         51006   51022
# 1               XOCHIMILCO       23959       23959         23959   23965
# 2                  TLAHUAC       17691       17691         17691   17697
# 3                  TLALPAN       44999       44999         44999   45009
# 4      VENUSTIANO CARRANZA       44980       44980         44980   44985
# 5               CUAUHTEMOC      128319      128319        128319  128349
# 6             AZCAPOTZALCO       38592       38592         38592   38596
# 7               IZTAPALAPA      116685      116685        116685  116710
# 8            BENITO JUAREZ       68835       68835         68835   68851
# 9    CUAJIMALPA DE MORELOS       11096       11096         11096   11098
# 10        GUSTAVO A MADERO       78038       78038         78038   78051
# 11          MIGUEL HIDALGO       52248       52248         52248   52264
# ...

# %%
años_df = PGJ_input.groupby("año_hechos")["delito"].count()
años_df
# Out:
# año_hechos
# 1906.0         1
# 1915.0         2
# 1930.0         1
# 1942.0         1
# 1954.0         1
# 1955.0         2
# 1956.0         2
# 1957.0         1
# 1958.0         1
# 1960.0         1
# 1962.0         1
# 1964.0         2
# 1965.0         1
# 1966.0         2
# 1968.0         1
# 1969.0         3
# 1970.0         2
# 1971.0         2
# 1972.0         4
# 1973.0         1
# 1974.0         2
# 1975.0         3
# 1976.0         3
# 1977.0         1
# 1978.0         3
# 1979.0         1
# 1980.0         3
# 1981.0         4
# 1982.0         3
# 1983.0         9
#            ...
# 1990.0        15
# 1991.0        10
# 1992.0        21
# 1993.0        18
# 1994.0        15
# 1995.0        15
# 1996.0        21
# 1997.0        31
# 1998.0        33
# 1999.0        31
# 2000.0        60
# 2001.0       152
# 2002.0        51
# 2003.0        80
# 2004.0       117
# 2005.0       144
# 2006.0       199
# 2007.0       253
# 2008.0       349
# 2009.0       367
# 2010.0       675
# ...

# %%
PGJ_input_alcaldia=PGJ_input.groupby("alcaldia_hechos").count()
PGJ_input_alcaldia
# Out:
# alcaldia_hechos         año_hechos  delito
# ALVARO OBREGON          51006       51022     1
# AZCAPOTZALCO            38592       38596     1
# BENITO JUAREZ           68835       68851     1
# COYOACAN                52897       52916     1
# CUAJIMALPA DE MORELOS   11096       11098     1
# CUAUHTEMOC              128319      128349    1
# GUSTAVO A MADERO        78038       78051     1
# IZTACALCO               33597       33603     1
# IZTAPALAPA              116685      116710    1
# LA MAGDALENA CONTRERAS  11730       11731     1
# MIGUEL HIDALGO          52248       52264     1
# MILPA ALTA              5019        5019      1
# TLAHUAC                 17691       17697     1
# TLALPAN                 44999       45009     1
# VENUSTIANO CARRANZA     44980       44985     1
# Name: delito, dtype: int64

# %%
rides_per_city = PGJ_input.groupby(["año_hechos","alcaldia_hechos"])["delito"].value_counts()
rides_per_city.head(15)
# Out:
# año_hechos  alcaldia_hechos   delito
# 1906.0      IZTAPALAPA        VIOLENCIA FAMILIAR                                   1
# 1915.0      CUAUHTEMOC        ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA       1
#             XOCHIMILCO        FRAUDE                                               1
# 1930.0      GUSTAVO A MADERO  ROBO DE OBJETOS                                      1
# 1942.0      COYOACAN          VIOLENCIA FAMILIAR                                   1
# 1954.0      TLALPAN           TENTATIVA DE EXTORSION                               1
# 1955.0      CUAUHTEMOC        ROBO A PASAJERO / CONDUCTOR DE TAXI CON VIOLENCIA    1
#             TLALPAN           ROBO A CASA HABITACION SIN VIOLENCIA                 1
# 1956.0      CUAUHTEMOC        FALSEDAD DE DECLARACIONES                            1
#             IZTACALCO         AMENAZAS                                             1
# 1957.0      IZTACALCO         DENUNCIA DE HECHOS                                   1
# ...
