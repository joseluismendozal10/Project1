# %%
import pandas as pd
import json as json
import matplotlib.pyplot as plt 

PGJ_input=pd.read_csv("Carpetas de Investigación PGJ CDMX.csv",sep=";")
PGJ_input.head()
# Out:
#    año_hechos mes_hechos         fecha_hechos  \
# 0      2017.0      Junio  2017-06-19 10:00:00
# 1      2016.0  Noviembre  2016-11-15 12:00:00
# 2      2017.0      Junio  2017-06-19 05:00:00
# 3      2017.0      Junio  2017-06-19 06:00:00
# 4      2017.0      Marzo  2017-03-13 12:00:00
#
#                                               delito  \
# 0                       ROBO A NEGOCIO SIN VIOLENCIA
# 1                                            DESPOJO
# 2  ROBO A PASAJERO / CONDUCTOR DE TAXI CON VIOLENCIA
# 3     ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 4                                 ABUSO DE CONFIANZA
#
#                                     categoria_delito  \
# 0                             DELITO DE BAJO IMPACTO
# 1                             DELITO DE BAJO IMPACTO
# 2                             DELITO DE BAJO IMPACTO
# 3  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
# 4                             DELITO DE BAJO IMPACTO
#
# ...

# %%
PGJ_input_años=PGJ_input.groupby("año_hechos").count()
PGJ_input_años
# Out:
#             mes_hechos  fecha_hechos  delito  categoria_delito  fiscalía  \
# año_hechos
# 1906.0               1             1       1                 1         1
# 1915.0               2             2       2                 2         2
# 1930.0               1             1       1                 1         1
# 1942.0               1             1       1                 1         1
# 1954.0               1             1       1                 1         1
# 1955.0               2             2       2                 2         2
# 1956.0               2             2       2                 2         2
# 1957.0               1             1       1                 1         1
# 1958.0               1             1       1                 1         1
# 1960.0               1             1       1                 1         1
# 1962.0               1             1       1                 1         1
# 1964.0               2             2       2                 2         2
# ...

# %%
años_df = PGJ_input_años.loc[2016.0:2019.0]
años_df
# Out:
#             mes_hechos  fecha_hechos  delito  categoria_delito  fiscalía  \
# año_hechos
# 2016.0          194007        194007  194007            194007    194007
# 2017.0          225329        225329  225329            225329    225329
# 2018.0          248953        248953  248953            248953    248953
# 2019.0           93846         93846   93846             93846     93846
#
#             agencia  unidad_investigacion  colonia_hechos  alcaldia_hechos  \
# año_hechos
# 2016.0       194007                193818          186531           193705
# 2017.0       225329                225329          216066           225111
# 2018.0       248953                248953          239431           248662
# 2019.0        93846                 93846           90703            93826
#
#             fecha_inicio  mes_inicio  ao_inicio  calle_hechos  calle_hechos2  \
# año_hechos
# 2016.0            194007      194007     194007        193453          89555
# ...
